# %% [markdown]
# ---
#
# # 🔥 INFOSYS – Probability Interview Questions (with Answers)
#
# ### Q1. Difference between independent and mutually exclusive events?
#
# **Answer (Say this):**
# “Independent events do not affect each other’s probability, while mutually exclusive events cannot occur together. For independent events, P(A ∩ B) = P(A)P(B). For mutually exclusive events, P(A ∩ B) = 0.”
#
# (Mutually Exclusive)
# Coin Toss:
#
# Event A = getting heads , Event B = getting tails.
# → You can’t get both heads and tails in one toss, so they’re mutually exclusive.
#
# **Testing:** Concept clarity
#
# ---
#
# ### Q2. What is conditional probability? Give a real example.
#
# **Answer:**
# “Conditional probability measures the probability of an event given another has occurred. For example, probability that an email is spam given it contains the word ‘free’.”
#
# **Testing:** Real-world mapping
#
# ---
#
# ### Q3. Why is normal distribution important in data science?
#
# **Answer:**
# “Due to the Central Limit Theorem, many real-world variables approximate a normal distribution, making it useful for modeling errors, noise, and confidence intervals.”
#
# **Testing:** Statistical intuition
#
# ---
#
# ### Q4. What is empirical probability?
#
# **Answer:**
# “It is probability derived from observed data rather than assumptions. In ML, we estimate probabilities using historical datasets.”
#
# ---
#
# # 🔥 AMAZON – Probability Interview Questions (with Answers)
#
# Amazon focuses on **applied reasoning + decision making**.
#
# ---
#
# ### Q5. You toss a fair coin 10 times. What is the probability of getting heads on the 11th toss?
#
# **Answer:**
# “The probability remains 0.5 because coin tosses are independent events. Previous outcomes do not affect future ones.”
#
# **Testing:** Independence understanding
#
# ---
#
# ### Q6. What is Bayes’ Theorem and where is it used?
#
# **Answer:**
# “Bayes’ theorem updates prior beliefs using new evidence. It is used in spam detection, recommendation systems, and Naive Bayes classifiers.”
#
# **Testing:** Business + ML link
#
# ---
#
# ### Q7. Explain false positives and false negatives using probability.
#
# **Answer:**
# “A false positive occurs when a model predicts an event that didn’t happen, while a false negative occurs when it misses an actual event. Their probabilities are critical in domains like healthcare and fraud detection.”
#
# **Testing:** Risk awareness
#
# ---
#
# ### Q8. Why is log loss preferred over accuracy?
#
# **Answer:**
# “Log loss penalizes confident wrong predictions heavily and evaluates probability quality, whereas accuracy ignores prediction confidence.”
#
# **Testing:** Model evaluation depth
#
# ---
#
# ### Q9. Explain Poisson distribution with an Amazon example.
#
# **Answer:**
# “Poisson distribution models event counts over time. For Amazon, it can model the number of orders received per minute.”
#
# **Testing:** Practical application
#
# ---
#
# # 🔥 GOOGLE – Probability Interview Questions (with Answers)
#
# Google tests **depth + intuition + communication**.
#
# ---
#
# ### Q10. Explain Central Limit Theorem in simple terms.
#
# **Answer:**
# “No matter the original distribution, the average of sufficiently large random samples tends to follow a normal distribution.”
#
# **Testing:** Teaching ability
#
# ---
#
# ### Q11. What assumptions does Naive Bayes make?
#
# **Answer:**
# “It assumes features are conditionally independent given the class label. Despite being a strong assumption, it works well in practice.”
#
# **Testing:** Model realism
#
# ---
#
# ### Q12. What is expectation in probability?
#
# **Answer:**
# “Expectation is the long-run average value of a random variable and represents the average outcome over repeated experiments.”
#
# **Testing:** Mathematical intuition
#
# ---
#
# ### Q13. How does probability relate to uncertainty in ML?
#
# **Answer:**
# “Probability quantifies uncertainty, allowing models to express confidence in predictions rather than just hard decisions.”
#
# **Testing:** ML philosophy
#
# ---
#
# ### Q14. Explain bias–variance tradeoff probabilistically.
#
# **Answer:**
# “Bias reflects error from incorrect assumptions, while variance reflects sensitivity to data. The goal is to minimize total expected error.”
#
# **Testing:** Theoretical maturity
#
# ---
#
# ### Q15. Can two events be both independent and mutually exclusive?
#
# **Answer (Key Google Question):**
# “Only if at least one event has probability zero. Otherwise, independent events must be able to occur together.”
#
# **Testing:** Deep concept clarity
#
# ---
#
# # 🔥 ULTRA-IMPORTANT INTERVIEW PUZZLES (ALL COMPANIES)
#
# ### Q16. If disease prevalence is 1% and test accuracy is 99%, is a positive result reliable?
#
# **Answer:**
# “No. Due to low base rate, false positives dominate. Bayes’ theorem is needed to compute the true probability.”
#
# **Testing:** Bayesian thinking
#
# ---
#
# ### Q17. Why do ML models output probabilities instead of labels?
#
# **Answer:**
# “Probabilities allow threshold tuning, uncertainty estimation, and better business decision-making.”
#
# **Testing:** Production thinking
#
# ---
#
# # 🎯 HOW TO ANSWER LIKE A TOP CANDIDATE
#
# Always structure answers as:
#
# **Definition → Intuition → Real example → ML relevance**
#
# ---

# %% [markdown]
# Awesome choice. Below are **30 Google-level probability puzzles** with **clear, interview-ready solutions**.
# These are the **exact style Google uses**: intuition > formulas, calm reasoning, and clean explanation.
#
# I’ve grouped them by **concept**, and each answer shows **how you should speak in an interview**.
#
# ---
#
# # 🧠 30 GOOGLE-LEVEL PROBABILITY PUZZLES (WITH SOLUTIONS)
#
# ---
#
# ## 🔹 INDEPENDENCE & CONDITIONAL PROBABILITY
#
# ### **1. Two coin tosses. What is the probability of at least one head?**
#
# **Solution:**
# Possible outcomes: HH, HT, TH, TT
# Favourable = 3
# [
# P = 3/4
# ]
#
# ---
#
# ### **2. Given that one coin toss is a head, what’s the probability both are heads?**
#
# **Solution:**
# Valid outcomes: HH, HT, TH
# Only HH satisfies
# [
# P = 1/3
# ]
#
# ---
#
# ### **3. You toss a fair coin until first head appears. Expected number of tosses?**
#
# **Solution:**
# This follows geometric distribution
# [
# E(X) = \frac{1}{p} = 2
# ]
#
# ---
#
# ### **4. Probability that two dice show same number?**
#
# **Solution:**
# Favourable = 6
# Total = 36
# [
# P = 1/6
# ]
#
# ---
#
# ### **5. Are two consecutive coin tosses independent?**
#
# **Solution:**
# Yes, outcome of one does not affect the other.
#
# ---
#
# ## 🔹 BAYES & CONDITIONAL REASONING
#
# ### **6. Disease prevalence is 1%, test accuracy 99%. You test positive. Probability you actually have disease?**
#
# **Solution:**
# False positives dominate. Actual probability ≈ **50% or less**, not 99%.
# Bayes’ theorem must be used.
#
# (Key insight matters more than exact number)
#
# ---
#
# ### **7. Two bags: one has 2 black balls, other has 1 black & 1 white. Random bag chosen, black ball drawn. Probability bag was first one?**
#
# **Solution:**
# [
# P = \frac{2/4}{(2/4 + 1/4)} = 2/3
# ]
#
# ---
#
# ### **8. Why do base rates matter in prediction?**
#
# **Solution:**
# Ignoring base rates leads to incorrect conclusions even with high accuracy models.
#
# ---
#
# ## 🔹 EXPECTATION & INTUITION
#
# ### **9. Expected number on a fair die roll?**
#
# **Solution:**
# [
# (1+2+3+4+5+6)/6 = 3.5
# ]
#
# ---
#
# ### **10. Expected number of heads in 100 coin tosses?**
#
# **Solution:**
# [
# 100 \times 0.5 = 50
# ]
#
# ---
#
# ### **11. Expected number of trials until first success if p = 0.2?**
#
# **Solution:**
# [
# E = 1/p = 5
# ]
#
# ---
#
# ## 🔹 COMBINATORICS + PROBABILITY
#
# ### **12. Probability of drawing an Ace from a deck?**
#
# **Solution:**
# [
# 4/52 = 1/13
# ]
#
# ---
#
# ### **13. Probability of two aces in two draws without replacement?**
#
# **Solution:**
# [
# (4/52) \times (3/51)
# ]
#
# ---
#
# ### **14. Probability of at least one Ace in two draws?**
#
# **Solution:**
# [
# 1 - P(\text{no ace}) = 1 - (48/52 \times 47/51)
# ]
#
# ---
#
# ## 🔹 GOOGLE-STYLE LOGIC PUZZLES
#
# ### **15. You flip a coin 10 times, all heads. Probability of head next?**
#
# **Solution:**
# 0.5 — independence.
#
# ---
#
# ### **16. Can two events be independent and mutually exclusive?**
#
# **Solution:**
# Only if one event has probability zero.
#
# ---
#
# ### **17. If P(A) = 0.7, P(B) = 0.6, what is minimum P(A ∩ B)?**
#
# **Solution:**
# [
# 0.7 + 0.6 - 1 = 0.3
# ]
#
# ---
#
# ### **18. What is maximum P(A ∩ B)?**
#
# **Solution:**
# [
# \min(0.7, 0.6) = 0.6
# ]
#
# ---
#
# ## 🔹 DISTRIBUTIONS & REAL-WORLD THINKING
#
# ### **19. Which distribution models number of emails per hour?**
#
# **Solution:**
# Poisson distribution.
#
# ---
#
# ### **20. Time between arrivals of customers follows which distribution?**
#
# **Solution:**
# Exponential distribution.
#
# ---
#
# ### **21. Why is Gaussian everywhere?**
#
# **Solution:**
# Due to Central Limit Theorem.
#
# ---
#
# ## 🔹 MARKOV & RANDOM PROCESSES
#
# ### **22. What is a Markov process?**
#
# **Solution:**
# Future depends only on present, not past.
#
# ---
#
# ### **23. Random walk expectation after n steps?**
#
# **Solution:**
# Zero — symmetry.
#
# ---
#
# ## 🔹 ADVANCED GOOGLE PUZZLES
#
# ### **24. Three boxes:**
#
# * BB
# * WW
# * BW
#
# Pick one box and one ball → ball is black. Probability other ball is black?
#
# **Solution:**
# Only possible cases: BB or BW
# BB has 2 black possibilities
# BW has 1
# [
# P = 2/3
# ]
#
# ---
#
# ### **25. Why do we use log probabilities instead of raw probabilities?**
#
# **Solution:**
# Avoid underflow and convert multiplication into addition.
#
# ---
#
# ### **26. Expected number of fixed points in random permutation?**
#
# **Solution:**
# 1 (classic result)
#
# ---
#
# ### **27. What is entropy intuitively?**
#
# **Solution:**
# Measure of uncertainty or information.
#
# ---
#
# ### **28. Why is KL divergence not symmetric?**
#
# **Solution:**
# It measures information loss from one distribution to another.
#
# ---
#
# ### **29. Why does Naive Bayes work despite false independence assumption?**
#
# **Solution:**
# Because classification depends on relative probabilities.
#
# ---
#
# ### **30. Why do ML models output probabilities instead of decisions?**
#
# **Solution:**
# Probabilities allow uncertainty handling, threshold tuning, and risk control.
#
# ---
