# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../EDA/CustomerChurn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.TotalCharges = pd.to_numeric(df.TotalCharges,errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.dropna(how='any',inplace=True)

# %%
df.Churn.value_counts()/len(df)*100
# Out:
# Churn
# No     73.421502
# Yes    26.578498
# Name: count, dtype: float64

# %%
# Churn Rate  = 27%

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
X = df.drop(['customerID','Churn'],axis=1)
y = df.Churn.values

# %%
X = pd.get_dummies(
    X,
    columns=['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod'],
    drop_first=True,
    dtype=int
)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test,y_train, y_test = train_test_split(X, y, test_size=0.25, train_size=0.75)

# %%
(len(y_test)/len(df))*100
# Out:
# 25.0

# %%
type(X_test)
# Out:
# pandas.core.frame.DataFrame

# %%
X_test
# Out:
#       tenure  MonthlyCharges  TotalCharges  gender_Male  SeniorCitizen_1  \
# 2500      50           75.50       4025.60            1                0
# 5430      10           72.15        794.25            1                0
# 5318      32           73.60       2316.85            0                0
# 5657      18           94.75       1691.90            1                0
# 3918      20           90.20       1776.55            1                0
# ...      ...             ...           ...          ...              ...
# 2339      21           94.25       1973.75            0                1
# 1346      14           87.25       1258.60            0                0
# 4470       7           44.65        322.50            1                0
# 80         1           79.35         79.35            0                0
# 491        2           59.00        114.15            0                0
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# ...

# %%
# Feature Scaling

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

# %%
X_train_sc
# Out:
# array([[ 1.57020247,  1.34922986,  2.24020998, ..., -0.52571806,
#         -0.71224139, -0.54301809],
#        [ 0.75632862, -1.47801015, -0.54805759, ..., -0.52571806,
#         -0.71224139,  1.84155927],
#        [ 1.57020247, -1.46309505, -0.34991653, ..., -0.52571806,
#         -0.71224139, -0.54301809],
#        ...,
#        [-1.19696862,  0.30020118, -0.90632107, ...,  1.90216026,
#         -0.71224139, -0.54301809],
#        [ 1.04118447,  0.00687089,  0.66086455, ...,  1.90216026,
#         -0.71224139, -0.54301809],
#        [ 1.28534662,  0.36649051,  1.11260242, ..., -0.52571806,
#         -0.71224139, -0.54301809]])

# %% [markdown]
# KNN Classifier

# %%
# Call the knn Classifier
from sklearn.neighbors import KNeighborsClassifier

#Initiating
model = KNeighborsClassifier()

#Passing the data to classifier
model.fit(X_train_sc,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = model.predict(X_test_sc)

# %%
# Classifcation metrics to check how model is performing

from sklearn.metrics import accuracy_score

print(accuracy_score(y_test,y_pred)*100)
# Out:
# 75.99544937428895

# %% [markdown]
# Decision Tree Clasifier

# %%
# Call the DT Classifier

from sklearn.tree import DecisionTreeClassifier

#Initiating the classifier
model_dt = DecisionTreeClassifier()

#Passing the data to classifier
model_dt.fit(X_train_sc,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dt = model_dt.predict(X_test_sc)

# %%
print(accuracy_score(y_test,y_pred_dt)*100)
# Out:
# 72.07053469852104

# %% [markdown]
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# Initiating

model_rf = RandomForestClassifier(n_estimators=200)
# sometimes accuracy increases by increasing n_estimators that is number of trees in the forest

model_rf.fit(X_train_sc,y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
y_pred_rf = model_rf.predict(X_test_sc)

# %%
print(accuracy_score(y_test,y_pred_rf)*100)
# Out:
# 79.5221843003413

# %%
y_test
# Out:
# array(['No', 'Yes', 'No', ..., 'No', 'Yes', 'No'], dtype=object)

# %%
from sklearn.metrics import classification_report

knn_report = classification_report(y_test,y_pred)
dt_report = classification_report(y_test,y_pred_dt)
rf_report = classification_report(y_test,y_pred_rf)

# %%
print(knn_report)
# Out:
#               precision    recall  f1-score   support
#
#           No       0.83      0.85      0.84      1313
#          Yes       0.53      0.49      0.51       445
#
#     accuracy                           0.76      1758
#    macro avg       0.68      0.67      0.68      1758
# weighted avg       0.75      0.76      0.76      1758

# %%
print(dt_report)
# Out:
#               precision    recall  f1-score   support
#
#           No       0.82      0.80      0.81      1313
#          Yes       0.45      0.48      0.46       445
#
#     accuracy                           0.72      1758
#    macro avg       0.64      0.64      0.64      1758
# weighted avg       0.73      0.72      0.72      1758

# %%
print(rf_report)
# Out:
#               precision    recall  f1-score   support
#
#           No       0.84      0.90      0.87      1313
#          Yes       0.62      0.49      0.55       445
#
#     accuracy                           0.80      1758
#    macro avg       0.73      0.69      0.71      1758
# weighted avg       0.78      0.80      0.79      1758

# %% [markdown]
# ## Accuracy Scores
#
# ### KNN - 76%
# ### DT - 74%
# ### RF - 79%

# %% [markdown]
# # New Classifiers

# %% [markdown]
# #### Naive Bayes Classifier

# %%
from sklearn.naive_bayes import BernoulliNB

model_nb = BernoulliNB()

model_nb.fit(X_train_sc,y_train)

y_pred_nb = model_nb.predict(X_test_sc)

print(accuracy_score(y_test,y_pred_nb)*100)
# Out:
# 71.95676905574516

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

model_lr = LogisticRegression()

model_lr.fit(X_train_sc,y_train)

y_pred_lr = model_lr.predict(X_test_sc)

print(accuracy_score(y_test,y_pred_lr)*100)
# Out:
# 79.46530147895335

# %% [markdown]
# #### SVM Classifier

# %%
from sklearn.svm import SVC

model_svm = SVC()

model_svm.fit(X_train_sc,y_train)

y_pred_svm = model_svm.predict(X_test_sc)

print(accuracy_score(y_test,y_pred_svm)*100)
# Out:
# 79.57906712172924

# %%
naive_report = classification_report(y_test,y_pred_nb)
logistic_report = classification_report(y_test,y_pred_lr)
svm_report = classification_report(y_test,y_pred_svm)

# %%
print(naive_report)
# Out:
#               precision    recall  f1-score   support
#
#           No       0.90      0.70      0.79      1313
#          Yes       0.47      0.77      0.58       445
#
#     accuracy                           0.72      1758
#    macro avg       0.68      0.74      0.69      1758
# weighted avg       0.79      0.72      0.74      1758

# %%
print(logistic_report)
# Out:
#               precision    recall  f1-score   support
#
#           No       0.84      0.89      0.87      1313
#          Yes       0.61      0.51      0.56       445
#
#     accuracy                           0.79      1758
#    macro avg       0.73      0.70      0.71      1758
# weighted avg       0.78      0.79      0.79      1758

# %%
print(svm_report)
# Out:
#               precision    recall  f1-score   support
#
#           No       0.83      0.91      0.87      1313
#          Yes       0.63      0.47      0.54       445
#
#     accuracy                           0.80      1758
#    macro avg       0.73      0.69      0.70      1758
# weighted avg       0.78      0.80      0.78      1758

# %% [markdown]
# ## Ensemble Techniques

# %% [markdown]
# ##### AdaBoost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier

model_ada = AdaBoostClassifier(n_estimators=200)

model_ada.fit(X_train_sc,y_train)

y_pred_ada = model_ada.predict(X_test_sc)

print(accuracy_score(y_test,y_pred_ada)*100)
# Out:
# 80.09101251422071

# %% [markdown]
# ##### Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

model_gb = GradientBoostingClassifier(n_estimators=200)

model_gb.fit(X_train_sc,y_train)

y_pred_gb = model_ada.predict(X_test_sc)

print(accuracy_score(y_test,y_pred_gb)*100)
# Out:
# 80.09101251422071

# %% [markdown]
# ##### XGBoost

# %%
y_train[y_train=='No']=0
y_train[y_train=='Yes']=1
y_test[y_test=='No']=0
y_test[y_test=='Yes']=1

# %%
y_test = y_test.astype(int)
y_train = y_train.astype(int)

# %%
from xgboost import XGBClassifier

model_xgb = XGBClassifier(n_estimators=200)

model_xgb.fit(X_train_sc,y_train)

y_pred_xgb = model_xgb.predict(X_test_sc)

print(accuracy_score(y_test,y_pred_xgb)*100)
# Out:
# 78.04323094425484

# %% [markdown]
# ### Needs Hyper Parameter Optimisation to give proper results.
